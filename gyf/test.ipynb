# %%
from torch.nn.functional import relu
from mmdet.apis import init_detector,inference_detector,show_result_pyplot
import mmcv
import os
import glob
from PIL import Image
from torchvision.transforms import ToTensor

config_file = '/home/gyf/projects/mmdetection/configs/faster_rcnn/faster_rcnn_r50_fpn_1x_coco.py'
checkpoint_file = '/home/gyf/projects/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth'

model = init_detector(config_file,checkpoint_file,device="cuda:3")
img = '/home/gyf/projects/mmdetection/demo/demo.jpg'
result = inference_detector(model,img)
print(type(result),len(result),'\n\n',result,'\n\n',result[0])

show_result_pyplot(model,img,result)
# model.show_result(img,result,out_file=f'./result.img')
# Out:
# load checkpoint from local path: /home/gyf/projects/mmdetection/checkpoints/faster_rcnn_r50_fpn_1x_coco_20200130-047c8118.pth
# <class 'list'> 80
#
#  [array([[3.75348572e+02, 1.19171005e+02, 3.81950867e+02, 1.34460617e+02,
#         1.35454819e-01],
#        [5.32362000e+02, 1.09554726e+02, 5.40526550e+02, 1.25222633e+02,
#         8.88788104e-02],
#        [3.61124298e+02, 1.09049202e+02, 3.68625610e+02, 1.22483063e+02,
#         7.20717609e-02]], dtype=float32), array([], shape=(0, 5), dtype=float32), array([[6.09650024e+02, 1.13805901e+02, 6.34511658e+02, 1.36951904e+02,
#         9.88766134e-01],
#        [4.81773712e+02, 1.10480995e+02, 5.22459717e+02, 1.30407104e+02,
#         9.87157285e-01],
#        [1.01820683e+00, 1.12144722e+02, 6.04374275e+01, 1.44173752e+02,
#         9.83206093e-01],
#        [2.94623749e+02, 1.17035233e+02, 3.78022675e+02, 1.50550858e+02,
#         9.71326649e-01],
#        [3.96328979e+02, 1.11203323e+02, 4.32490540e+02, 1.32729263e+02,
# ...

# %%
import os
import skimage.io as io

img = io.imread(os.path.join('/home/gyf/projects/mmdetection/data/sockets/train/','00001.jpg'))

print(img.shape[:2])
# Out:
# (1440, 1080)
